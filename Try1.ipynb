# %%
import matplotlib.pyplot as plt
import numpy as np
from mtcnn.mtcnn import MTCNN

# %%
path = ".\data\subject01.normal"
pixels = plt.imread(path)
plt.imshow(pixels)

rgb_pixels = np.stack((pixels, pixels ,pixels), axis = 2)
print(rgb_pixels.shape)
plt.show()
# Out:
# (243, 320, 3)

# %%
detector = MTCNN()

result = detector.detect_faces(rgb_pixels)
result
# Out:
# [{'box': [118, 53, 123, 158],
#   'confidence': 0.9985021352767944,
#   'keypoints': {'nose': [180, 138],
#    'mouth_right': [206, 172],
#    'right_eye': [208, 111],
#    'left_eye': [152, 111],
#    'mouth_left': [155, 171]}}]
